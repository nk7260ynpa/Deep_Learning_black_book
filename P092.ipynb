# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)

# %%
classes = 10
y_train = np_utils.to_categorical(y_train, classes)
y_test = np_utils.to_categorical(y_test, classes)

# %%
input_size = 784
batch_size = 100
hidden_neurons = 100
epochs = 15

# %%
model = Sequential()
model.add(Dense(hidden_neurons, input_dim=input_size))
model.add(Activation('sigmoid'))
model.add(Dense(classes, input_dim=hidden_neurons))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='sgd')

# %%
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs,verbose=2)
# Out:
# Epoch 1/15
#  - 3s - loss: 0.9724 - acc: 0.7584
# Epoch 2/15
#  - 2s - loss: 0.4987 - acc: 0.8795
# Epoch 3/15
#  - 2s - loss: 0.3994 - acc: 0.8973
# Epoch 4/15
#  - 2s - loss: 0.3513 - acc: 0.9092
# Epoch 5/15
#  - 2s - loss: 0.3185 - acc: 0.9161
# Epoch 6/15
#  - 2s - loss: 0.2970 - acc: 0.9208
# Epoch 7/15
#  - 2s - loss: 0.2758 - acc: 0.9259
# Epoch 8/15
#  - 2s - loss: 0.2620 - acc: 0.9287
# Epoch 9/15
#  - 2s - loss: 0.2507 - acc: 0.9317
# Epoch 10/15
#  - 2s - loss: 0.2422 - acc: 0.9338
# Epoch 11/15
#  - 2s - loss: 0.2325 - acc: 0.9366
# Epoch 12/15
#  - 2s - loss: 0.2253 - acc: 0.9384
# Epoch 13/15
#  - 2s - loss: 0.2143 - acc: 0.9407
# Epoch 14/15
#  - 2s - loss: 0.2081 - acc: 0.9432
# Epoch 15/15
#  - 2s - loss: 0.2049 - acc: 0.9443

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print('Test accuracy', score[1])
# Out:
# 10000/10000 [==============================] - 0s 44us/step
# Test accuracy 0.9415

# %%
weights = model.layers[0].get_weights()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
w = weights[0].T
for neuron in range(hidden_neurons):
    plt.imshow(np.reshape(w[neuron], (28, 28)), cmap=cm.Greys_r)
    plt.show()
